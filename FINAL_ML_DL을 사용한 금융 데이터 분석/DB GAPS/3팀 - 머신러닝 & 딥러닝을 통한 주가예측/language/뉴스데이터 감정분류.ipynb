# %% [markdown]
# # 모델 불러오기

# %%
# !pip install transformers==4.8.2
# !pip install tensorflow_addons

import pandas as pd
import numpy as np

import re
import os
import pickle 
import dill # for saving a function as a file
import logging # for changing the tf's logging level
from IPython.display import clear_output 

import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.keras import layers, initializers, losses, optimizers, metrics 

import transformers
from transformers import TFBertModel 

# 이번 실습에서 추가되었습니다
# !pip install sentencepiece==0.1.96
import sentencepiece as spm 
# !git clone https://github.com/monologg/KoBERT-Transformers.git 
# !mv KoBERT-Transformers/kobert_transformers/tokenization_kobert.py /content 
from tokenization_kobert import KoBertTokenizer 

# Tensorflow logging level 변경 
tf.get_logger().setLevel(logging.ERROR)

# clear the output after the installation
clear_output()

# %%
import datetime
from numba import jit

# %%
from google.colab import drive
drive.mount('/gdrive')

data_path = '/gdrive/MyDrive/colab_data/temp_data/' 


# 1) Load the Model-builder function
with open(data_path + 'model_koBERTfunction_v1.pkl', 'rb') as f: # 이번 실습에서 변경되었습니다
    create_model = dill.loads(pickle.load(f)) # use dill to pickle a python function

# 2) Load the Bert-tokenizer 
tokenizer = KoBertTokenizer.from_pretrained('monologg/kobert')

# 3) Create the model & load the Model-weights (from checkpoint file)
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='grpc://' + os.environ['COLAB_TPU_ADDR'])
tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)
strategy = tf.distribute.TPUStrategy(resolver) # Obsolete : tf.distribute.experimental.TPUStrategy()

with strategy.scope(): 
    model = create_model(max_length=64) 

checkpoint_path = '/gdrive/MyDrive/colab_data/temp_data/saved_models/'
model.load_weights(filepath=checkpoint_path + 'best_kobert_weights.h5') # 이번 실습에서 변경되었습니다
# Out:
# Mounted at /gdrive
# Downloading:   0%|          | 0.00/371k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/77.8k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/51.0 [00:00<?, ?B/s]
# INFO:absl:Entering into master device scope: /job:worker/replica:0/task:0/device:CPU:0
# Downloading:   0%|          | 0.00/426 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/369M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFBertModel.
#
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
def encoding(row):
    sentence = row['new'] # title encoding -> new
    SEQ_LEN = 64 # 최대 token 개수 이상의 값으로 임의로 설정

    # Tokenizing / Tokens to sequence numbers / Padding
    encoded_dict = tokenizer.encode_plus(text=re.sub("[^\s0-9a-zA-Zㄱ-ㅎㅏ-ㅣ가-힣]", "", sentence),
                                         padding='max_length', 
                                         truncation = True,
                                         max_length=SEQ_LEN) # SEQ_LEN == 128
    
    token_ids = np.array(encoded_dict['input_ids']).reshape(1, -1) # shape == (1, 128) : like appending to a list 
    token_masks = np.array(encoded_dict['attention_mask']).reshape(1, -1)
    token_segments = np.array(encoded_dict['token_type_ids']).reshape(1, -1)
    new_inputs = (token_ids, token_masks, token_segments)
    return new_inputs

# %%
def predict_sentiment(row):
    encode_sentence = row['encode']
    # Prediction
    prediction = model.predict(encode_sentence)
    predicted_probability = np.round(np.max(prediction) * 100, 2) # ex) [[0.0125517 0.9874483]] -> round(0.9874483 * 100, 2) -> round(98.74483, 2) -> 98.74
    predicted_class = ['부정', '긍정'][np.argmax(prediction, axis=1)[0]] # ex) ['부정', '긍정'][[1][0]] -> ['부정', '긍정'][1] -> '긍정'
    
    #print("{}% 확률로 {} 리뷰입니다.".format(predicted_probability, predicted_class))
    return predicted_class, predicted_probability

# %% [markdown]
# # 구글드라이브에서 뉴스 크롤링 데이터 가져오기

# %%
data_path = '/gdrive/MyDrive/colab_data/news_crawling_v3.csv'

# %%
news_df = pd.read_csv(data_path)
news_df.head()
# Out:
#    Unnamed: 0                                          Title            Date
# 0           0             [Asia마감] 中 '나홀로 돈풀기'에 환호…상하이 1.6%↑  2022년05월20일(금)
# 1           1  [마켓뷰] 코스피, 국내외 기관 매수에 1.8% 상승 마감...개인 1조 ‘팔자’  2022년05월20일(금)
# 2           2       [외환마감]강달러 진정+위안화 강세…환율, 10원 가량 내려 1260원대  2022년05월20일(금)
# 3           3             [마감시황]코스피, 하루 만에 2600선 회복…'바이든 효과'  2022년05월20일(금)
# 4           4          [시황종합] 코스피, 한미정상회담 수혜 기대감에 상승…2639.29  2022년05월20일(금)

# %%
news_df.loc[1,'Title']
# Out:
# '[마켓뷰] 코스피, 국내외 기관 매수에 1.8% 상승 마감...개인 1조 ‘팔자’'

# %% [markdown]
# # 헤드라인에서 대괄호 안의 문자 제거

# %%
import re
def delete_bracket(row):
  x = row['Title']
  pattern = r'\[([^]]+)\]'
  #x = '이건 [괄호 안의 불필요한 정보를] 삭제하는 코드다.' test code

  text = re.sub(pattern=pattern, repl='', string= x)
  return text

# %%
news_df['new'] = news_df.apply(delete_bracket, axis='columns')

# %%
news_df
# Out:
#        Unnamed: 0                                          Title  \
# 0               0             [Asia마감] 中 '나홀로 돈풀기'에 환호…상하이 1.6%↑
# 1               1  [마켓뷰] 코스피, 국내외 기관 매수에 1.8% 상승 마감...개인 1조 ‘팔자’
# 2               2       [외환마감]강달러 진정+위안화 강세…환율, 10원 가량 내려 1260원대
# 3               3             [마감시황]코스피, 하루 만에 2600선 회복…'바이든 효과'
# 4               4          [시황종합] 코스피, 한미정상회담 수혜 기대감에 상승…2639.29
# ...           ...                                            ...
# 35080       35080                        [원포인트]5년차 상승국면에서 부각될 주식
# 35081       35081                             코스닥시장 4대 트렌드에 주목하라
# 35082       35082                            올해 인터넷株 투자 "이것이 핵심"
# 35083       35083                                     외인은 1월에 산다
# 35084       35084                           (투자의맥)수출·증권株 비중확대 시점
#
#                  Date                                       new
# 0      2022년05월20일(금)                 中 '나홀로 돈풀기'에 환호…상하이 1.6%↑
# 1      2022년05월20일(금)   코스피, 국내외 기관 매수에 1.8% 상승 마감...개인 1조 ‘팔자’
# 2      2022년05월20일(금)        강달러 진정+위안화 강세…환율, 10원 가량 내려 1260원대
# 3      2022년05월20일(금)              코스피, 하루 만에 2600선 회복…'바이든 효과'
# 4      2022년05월20일(금)            코스피, 한미정상회담 수혜 기대감에 상승…2639.29
# ...               ...                                       ...
# 35080  2007년01월05일(금)                         5년차 상승국면에서 부각될 주식
# 35081  2007년01월03일(수)                        코스닥시장 4대 트렌드에 주목하라
# 35082  2007년01월03일(수)                       올해 인터넷株 투자 "이것이 핵심"
# 35083  2007년01월03일(수)                                외인은 1월에 산다
# 35084  2007년01월02일(화)                      (투자의맥)수출·증권株 비중확대 시점
#
# [35085 rows x 4 columns]

# %% [markdown]
# # predict

# %%
news_df['encode'] = news_df.apply(encoding, axis='columns')

# %%
news_df['label'], news_df['percent'] = news_df.apply(predict_sentiment, axis='columns')
# Out:
# INFO:absl:TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond/Identity:0' shape=(None, 64) dtype=int64>, <tf.Tensor 'cond/Identity_8:0' shape=(None, 64) dtype=int64>, <tf.Tensor 'cond/Identity_16:0' shape=(None, 64) dtype=int64>]

# %%
news_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-13c5cfba1a58> in <module>()
# ----> 1 news_df
#
# NameError: name 'news_df' is not defined

# %% [markdown]
# #test

# %%
temp = news_df[:100]
temp
# Out:
#     Unnamed: 0                                          Title            Date  \
# 0            0             [Asia마감] 中 '나홀로 돈풀기'에 환호…상하이 1.6%↑  2022년05월20일(금)
# 1            1  [마켓뷰] 코스피, 국내외 기관 매수에 1.8% 상승 마감...개인 1조 ‘팔자’  2022년05월20일(금)
# 2            2       [외환마감]강달러 진정+위안화 강세…환율, 10원 가량 내려 1260원대  2022년05월20일(금)
# 3            3             [마감시황]코스피, 하루 만에 2600선 회복…'바이든 효과'  2022년05월20일(금)
# 4            4          [시황종합] 코스피, 한미정상회담 수혜 기대감에 상승…2639.29  2022년05월20일(금)
# ..         ...                                            ...             ...
# 95          95          예상 웃돈 CPI에 나스닥 -3.18% 급락 [데일리 국제금융시장]  2022년05월12일(목)
# 96          96                      [유럽증시] 미 물가 오름폭 둔화에 동반 상승  2022년05월12일(목)
# 97          97       [마켓뷰] 코스피, 美 CPI 발표 앞두고 하락 마감…외인·기관 ‘팔자’  2022년05월11일(수)
# 98          98          '매도→관망' 분위기 반전…美관세 완화에 설레는 中[Asia 마감]  2022년05월11일(수)
# 99          99           [시황종합] 코스피, 2590선 하락 마감…美 CPI 앞두고 관망  2022년05월11일(수)
#
#                                          new  \
# 0                  中 '나홀로 돈풀기'에 환호…상하이 1.6%↑
# 1    코스피, 국내외 기관 매수에 1.8% 상승 마감...개인 1조 ‘팔자’
# 2         강달러 진정+위안화 강세…환율, 10원 가량 내려 1260원대
# 3               코스피, 하루 만에 2600선 회복…'바이든 효과'
# 4             코스피, 한미정상회담 수혜 기대감에 상승…2639.29
# ..                                       ...
# 95                 예상 웃돈 CPI에 나스닥 -3.18% 급락
# 96                        미 물가 오름폭 둔화에 동반 상승
# 97        코스피, 美 CPI 발표 앞두고 하락 마감…외인·기관 ‘팔자’
# 98              '매도→관망' 분위기 반전…美관세 완화에 설레는 中
# 99             코스피, 2590선 하락 마감…美 CPI 앞두고 관망
#
#                                                encode
# 0   ([[2, 1370, 7932, 6079, 1730, 7747, 5579, 5136...
# 1   ([[2, 4672, 1140, 1261, 1994, 6896, 547, 2670,...
# 2   ([[2, 807, 5795, 4360, 7227, 7050, 7941, 814, ...
# 3   ([[2, 4672, 4937, 1946, 553, 191, 6559, 5155, ...
# 4   ([[2, 4672, 4955, 6255, 7227, 6527, 7954, 2910...
# ..                                                ...
# 95  ([[2, 3405, 3528, 5866, 638, 337, 6896, 1370, ...
# 96  ([[2, 2149, 2136, 3417, 6117, 7734, 1778, 6896...
# 97  ([[2, 4672, 638, 337, 2251, 3185, 4933, 1908, ...
# 98  ([[2, 1990, 5474, 6165, 2482, 2219, 5474, 6579...
# 99  ([[2, 4672, 583, 237, 6559, 4933, 1908, 638, 3...
#
# [100 rows x 5 columns]

# %%
start=datetime.datetime.now()
temp['label'], temp['percent']  = zip(*temp.apply(predict_sentiment, axis='columns'))
end=datetime.datetime.now()
print(end-start)
# Out:
# 0:01:13.552580
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
start=datetime.datetime.now()
for i in range(100):
  sentence = news_df.loc[i,'Title']
  predicted_class, predicted_probability = predict_sentiment(sentence)
  news_df.loc[i,'label'] = predicted_class
  news_df.loc[i,'percent'] = predicted_probability
end=datetime.datetime.now()
print(end-start)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-4e2816066dce> in <module>()
#       2 for i in range(100):
#       3   sentence = news_df.loc[i,'Title']
# ----> 4   predicted_class, predicted_probability = predict_sentiment(sentence)
#       5   news_df.loc[i,'label'] = predicted_class
#       6   news_df.loc[i,'percent'] = predicted_probability
#
# <ipython-input-6-a50ca7896175> in predict_sentiment(row)
#       1
#       2 def predict_sentiment(row):
# ----> 3     encode_sentence = row['encode']
#       4     # Prediction
#       5     prediction = model.predict(encode_sentence)
#
# TypeError: string indices must be integers

# %%
temp[:20]
# Out:
#     Unnamed: 0                                          Title            Date  \
# 0            0             [Asia마감] 中 '나홀로 돈풀기'에 환호…상하이 1.6%↑  2022년05월20일(금)
# 1            1  [마켓뷰] 코스피, 국내외 기관 매수에 1.8% 상승 마감...개인 1조 ‘팔자’  2022년05월20일(금)
# 2            2       [외환마감]강달러 진정+위안화 강세…환율, 10원 가량 내려 1260원대  2022년05월20일(금)
# 3            3             [마감시황]코스피, 하루 만에 2600선 회복…'바이든 효과'  2022년05월20일(금)
# 4            4          [시황종합] 코스피, 한미정상회담 수혜 기대감에 상승…2639.29  2022년05월20일(금)
# 5            5            [코스닥 마감]바이든 방한 훈풍에 1.8%대 상승…880선 눈앞  2022년05월20일(금)
# 6            6           [오전시황] 기관 매수세에 코스피 2600선 회복…개인은 ‘팔자’  2022년05월20일(금)
# 7            7        [굿모닝 증시]美 증시 하락 마감…코스피 기술·리오프닝株 중심 반등할까  2022년05월20일(금)
# 8            8       [외환브리핑]102선으로 떨어진 달러인덱스…환율, 1260원대 하락 시도  2022년05월20일(금)
# 9            9           뉴욕증시, 물가·경기 우려에 하락…바이든 오늘 방한 [모닝브리핑]  2022년05월20일(금)
# 10          10           [일일펀드동향] 해외 주식형 펀드, 3거래일간 1900억원 순유입  2022년05월20일(금)
# 11          11      '약세장 문턱' 美증시 '흔들'...'실적실망' 시스코 13%↓[뉴욕마감]  2022년05월20일(금)
# 12          12       계속되는 인플레·수익감소 쇼크…나스닥 -0.26% [데일리 국제금융시장]  2022년05월20일(금)
# 13          13   [빅데이터로 본 재테크] 가상화폐시장 뒤흔든 '테라·루나 사태' 후폭풍 어디까지  2022년05월20일(금)
# 14          14                        [유럽증시] 인플레발 경기침체 공포에 하락  2022년05월20일(금)
# 15          15                    [Asia마감]美 따라 녹아내렸다…일본·홍콩 급락  2022년05월19일(목)
# 16          16       [마켓뷰] 美 급락 여파에 코스피 다시 2600선 밑…2차 전지株는 강세  2022년05월19일(목)
# 17          17             [마감시황]코스피, 기관 매도에 1.3% 하락…2590선 마감  2022년05월19일(목)
# 18          18     [시황종합]코스피 3일 만에 2600 무너져… 오후 낙폭 축소 2592 마감  2022년05월19일(목)
# 19          19        [외환마감]강달러에 국내증시 하락…환율, 11원 이상 올라 1270원대  2022년05월19일(목)
#
#                                          new  \
# 0                  中 '나홀로 돈풀기'에 환호…상하이 1.6%↑
# 1    코스피, 국내외 기관 매수에 1.8% 상승 마감...개인 1조 ‘팔자’
# 2         강달러 진정+위안화 강세…환율, 10원 가량 내려 1260원대
# 3               코스피, 하루 만에 2600선 회복…'바이든 효과'
# 4             코스피, 한미정상회담 수혜 기대감에 상승…2639.29
# 5                바이든 방한 훈풍에 1.8%대 상승…880선 눈앞
# 6              기관 매수세에 코스피 2600선 회복…개인은 ‘팔자’
# 7            美 증시 하락 마감…코스피 기술·리오프닝株 중심 반등할까
# 8          102선으로 떨어진 달러인덱스…환율, 1260원대 하락 시도
# 9              뉴욕증시, 물가·경기 우려에 하락…바이든 오늘 방한
# 10               해외 주식형 펀드, 3거래일간 1900억원 순유입
# 11       '약세장 문턱' 美증시 '흔들'...'실적실망' 시스코 13%↓
# 12              계속되는 인플레·수익감소 쇼크…나스닥 -0.26%
# 13            가상화폐시장 뒤흔든 '테라·루나 사태' 후폭풍 어디까지
# 14                          인플레발 경기침체 공포에 하락
# 15                       美 따라 녹아내렸다…일본·홍콩 급락
# 16        美 급락 여파에 코스피 다시 2600선 밑…2차 전지株는 강세
# 17              코스피, 기관 매도에 1.3% 하락…2590선 마감
# 18      코스피 3일 만에 2600 무너져… 오후 낙폭 축소 2592 마감
# 19         강달러에 국내증시 하락…환율, 11원 이상 올라 1270원대
#
#                                                encode label  percent
# 0   ([[2, 1370, 7932, 6079, 1730, 7747, 5579, 5136...    부정    71.32
# 1   ([[2, 4672, 1140, 1261, 1994, 6896, 547, 2670,...    부정    82.65
# 2   ([[2, 807, 5795, 4360, 7227, 7050, 7941, 814, ...    부정    60.08
# 3   ([[2, 4672, 4937, 1946, 553, 191, 6559, 5155, ...    긍정    70.98
# 4   ([[2, 4672, 4955, 6255, 7227, 6527, 7954, 2910...    긍정    75.46
# 5   ([[2, 2186, 7096, 5928, 2267, 7828, 517, 7970,...    긍정    79.92
# 6   ([[2, 1261, 1994, 6579, 6896, 4672, 553, 191, ...    부정    52.53
# 7   ([[2, 4294, 4933, 1908, 7537, 1289, 6122, 6964...    부정    95.60
# 8   ([[2, 533, 119, 6559, 7078, 1860, 1599, 7119, ...    부정    96.06
# 9   ([[2, 1543, 7316, 6705, 2136, 5425, 3499, 6896...    부정    94.81
# 10  ([[2, 5012, 4230, 7921, 4828, 589, 5381, 5337,...    부정    72.38
# 11  ([[2, 3212, 7178, 2120, 7611, 4294, 5199, 6742...    부정    99.45
# 12  ([[2, 984, 5889, 3758, 7761, 6050, 6639, 5341,...    부정    99.16
# 13  ([[2, 517, 5330, 6527, 7941, 7727, 6716, 1783,...    부정    93.10
# 14  ([[2, 3758, 7761, 6050, 6295, 961, 1054, 6896,...    부정    96.86
# 15  ([[2, 1835, 1494, 6797, 5678, 6074, 7131, 7939...    부정    99.35
# 16  ([[2, 1253, 3298, 7682, 6896, 4672, 1574, 553,...    부정    96.86
# 17  ([[2, 4672, 1261, 1990, 6896, 541, 4933, 137, ...    부정    99.16
# 18  ([[2, 4672, 589, 7126, 1946, 553, 191, 2095, 5...    부정    98.69
# 19  ([[2, 807, 5795, 6896, 1138, 7316, 6705, 4933,...    부정    98.86

# %% [markdown]
# # 날짜별 평균 감정 지수 구하기

# %%
temp.loc[temp['label'] == '긍정', 'label_index'] = 1
temp.loc[temp['label'] == '부정', 'label_index'] = 0
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
groups = temp.groupby('Date')

# %%
groups.mean()
# Out:
#                 Unnamed: 0    percent  label_index
# Date
# 2022년05월09일(월)         3.0  86.655714     0.000000
# 2022년05월11일(수)        97.5  87.075000     0.000000
# 2022년05월12일(목)        88.5  84.989286     0.142857
# 2022년05월13일(금)        75.0  73.754615     0.615385
# 2022년05월16일(월)        52.0  84.503636     0.272727
# 2022년05월17일(화)        28.0  77.969333     0.266667
# 2022년05월18일(수)        13.5  76.408571     0.500000

# %%
date_list = temp['Date'].unique()

# %%
for i in date_list:
  print(i)
# Out:
# 2022년05월09일(월)
# 2022년05월18일(수)
# 2022년05월17일(화)
# 2022년05월16일(월)
# 2022년05월13일(금)
# 2022년05월12일(목)
# 2022년05월11일(수)
